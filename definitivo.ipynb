# %% [markdown]
# <a href="https://colab.research.google.com/github/user086399/object-detector/blob/main/definitivo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip /content/drive/MyDrive/Data.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/Data.zip
#    creating: /content/Data/
#   inflating: /content/Data/data.yaml
#    creating: /content/Data/Train/
#    creating: /content/Data/Train/images/
#   inflating: /content/Data/Train/images/croped13_105636.jpg
#   inflating: /content/Data/Train/images/croped13_105639.jpg
#   inflating: /content/Data/Train/images/croped13_105811.jpg
#   inflating: /content/Data/Train/images/croped13_105816.jpg
#   inflating: /content/Data/Train/images/croped13_105820.jpg
#   inflating: /content/Data/Train/images/croped13_105822.jpg
#   inflating: /content/Data/Train/images/croped13_105825.jpg
#   inflating: /content/Data/Train/images/croped13_105828.jpg
#   inflating: /content/Data/Train/images/croped13_105832.jpg
#   inflating: /content/Data/Train/images/croped13_105844.jpg
#   inflating: /content/Data/Train/images/croped13_105902.jpg
#   inflating: /content/Data/Train/images/croped13_105904.jpg
#   inflating: /content/Data/Train/images/croped13_110109.jpg
# ...

# %%
# !git clone "https://github.com/ultralytics/yolov5.git"
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15921, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 15921 (delta 15), reused 20 (delta 8), pack-reused 15880
# Receiving objects: 100% (15921/15921), 14.66 MiB | 15.27 MiB/s, done.
# Resolving deltas: 100% (10910/10910), done.

# %%
# %cd yolov5
# %pip install -qr requirements.txt
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output
# Out:
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.5/617.5 kB 38.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.3/59.3 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.5 MB/s eta 0:00:00
# ...

# %%
# !python train.py --img 132 --batch 40 --epochs 300 --data ../Data/data.yaml  --weights 'yolov5l.pt' --cache
# Out:
# train: weights=yolov5l.pt, cfg=, data=../Data/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=40, imgsz=132, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-210-gdd10481 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...
